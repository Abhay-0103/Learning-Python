# %%
def make_briyani(style):
    if style not in ['Hyderabadi', 'Lucknowi', 'Kolkata']:
        raise ValueError(f"Unknown style: {style}")
    print(f"Making {style} briyani")

make_briyani('bengalururu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2     if style not in ['Hyderabadi', 'Lucknowi', 'Kolkata']:
#       3         raise ValueError(f"Unknown style: {style}")
#       4     print(f"Making {style} briyani")
#       5
# ----> 6 make_briyani('bengalururu')
#
# Cell In[1], line 3, in make_briyani(style)
#       1 def make_briyani(style):
#       2     if style not in ['Hyderabadi', 'Lucknowi', 'Kolkata']:
# ----> 3         raise ValueError(f"Unknown style: {style}")
#       4     print(f"Making {style} briyani")
#
# ValueError: Unknown style: bengalururu

# %%
def make_briyani(style):
    if style not in ['Hyderabadi', 'Lucknowi', 'Kolkata']:
        raise ValueError(f"Unknown style: {style}")
    print(f"Making {style} briyani")

make_briyani('Hyderabadi')
# Out:
# Making Hyderabadi briyani
