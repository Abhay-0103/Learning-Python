# %%
chai_menu = {"masala": 30, "ginger": 40}

chai_menu["elichi"] # KeyError: 'elichi'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 chai_menu = {"masala": 30, "ginger": 40}
#       2
# ----> 3 chai_menu["elichi"]
#
# KeyError: 'elichi'

# %%
chai_menu = {"masala": 30, "ginger": 40}

try:
    chai_menu["elichi"]
except KeyError:
    print("Sorry, The key you are trying to accss does not exist.")

print("Bacha hai tu mera")
# Out:
# Sorry, The key you are trying to accss does not exist.
# Bacha hai tu mera
